# %% [markdown]
# # Resting state fMRI preprocessing
# This notebook contains preprocessing tailored precision mapping in children.
#
# ### 1. General fMRI processing
# * Slice-time correction
# * Rigid realignment (also extract DVARS, FD, motion params)
# * Co-registration to the sMRI (T1-weighted structural MRI resampled to 2x2x2mm voxels)
#
# ### 2. Resting state processing
# * Derive temporal mask based on FD and DVARS
# * Demean and detrend
# * De-noise to remove:
#     - Mean timeseries for that voxel
#     - Component noise associated with white matter and CSF- delete the GM and smooth what is left
#     - Component noise associated with background signal - delete brain and smooth what's left
#     - the averaged timeseries
#     - motion regressors
#     - Motion derivatives (lagged 8 times)
#     - Squared derivatives (lagged 8 times)
# * Interpolate timepoints using spectral based interpolation
# * Bandpass filter
# * delete interpolated timepoints and concatenate runs
#
# ### 3. Cortical registration and CIFTI creation
# * Register fMRI to cortical surfaces
# * Make CIFTI file that includes cortical, subcortical, and cerebellar data

# %%
#import packages
from os import listdir, makedirs
from os.path import isdir
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber, FreeSurferSource # Data i/o
from nipype.interfaces.utility import IdentityInterface, Function     # utility
from nipype.pipeline.engine import Node, Workflow, MapNode, JoinNode        # pypeline engine
from nipype.interfaces.nipy.preprocess import Trim
from nipype.interfaces.ants import N4BiasFieldCorrection
from nipype.interfaces.fsl import SliceTimer, MCFLIRT, FLIRT, BET, Merge
from nipype.interfaces.fsl.utils import Reorient2Std, MotionOutliers
from nipype.interfaces.fsl.maths import ApplyMask, MeanImage
from nipype.interfaces.freesurfer import Resample, Binarize, BBRegister, MRIConvert
from nipype.algorithms.confounds import CompCor
from nipype.interfaces.afni.preprocess import Bandpass
from nipype.interfaces.afni.utils import AFNItoNIFTI
from pandas import DataFrame, read_csv

#set output file type for FSL to NIFTI_GZ
from nipype.interfaces.fsl.preprocess import FSLCommand
FSLCommand.set_default_output_type('NIFTI_GZ')

# MATLAB setup - Specify path to current SPM and the MATLAB's default mode
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('~/spm12/toolbox')
MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

# Set study variables
study_home = '/moochie/user_data/CamachoCat/5YOP'
raw_data =  '/moochie/study_data/5YOP/MRI_processing'
output_dir = study_home + '/proc/preprocessing'
workflow_dir = study_home + '/workflows'
custom_timings = study_home + '/misc/slice_timing.txt'
fs_dir = study_home + '/freesurfer'
session_info = read_csv(study_home + '/misc/session_info.csv',index_col=None)

subject_ids = session_info['subject_id'].unique().tolist()

sessions_lists = []
for sub in subject_ids:
    sessions_lists.append(session_info[session_info['subject_id']==sub]['run_name'].tolist())

subject_ids = list(map(str,subject_ids))
proc_cores = 6 # number of cores of processing for the workflows

interleave = True
TR = 1.1 # in seconds
slice_dir = 3 # 1=x, 2=y, 3=z
resampled_voxel_size = (2,2,2)

highpass_freq = 0.008 #in Hz
lowpass_freq = 0.09 #in Hz
# Out:
# 200106-14:07:27,506 nipype.utils INFO:
# 	 Running nipype version 1.2.3 (latest: 1.4.0)

# %%
## File handling Nodes

# Identity node- select subjects
subinfosource = Node(IdentityInterface(fields=['subject_id']),
                     name='subinfosource')
subinfosource.iterables = [('subject_id', subject_ids)]

# Datasink- where our select outputs will go
substitutions = [('_subject_id_', '')]
datasink = Node(DataSink(), name='datasink')
datasink.inputs.base_directory = output_dir
datasink.inputs.container = output_dir
datasink.inputs.substitutions = substitutions

# %% [markdown]
# ## Process T1 anat for fMRI processing
# 1. Resample skullstripped T1w anat
# 2. Resample segmentation
# 3. Create tissue masks:
#     - GM only
#     - Non-GM only
#     - Full brain (no ventricles)
#     - Full brain (with ventricles and dilated)
#     - Extra-cerebral space
# 4. Resample surfaces

# %%
def make_masks_freesurfer(aseg_nifti):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nibabel import load, save, Nifti1Image
    from numpy import zeros
    from nipype.interfaces.freesurfer import Binarize
    from os.path import abspath
    
    # load the subject's segmentation volumes
    aseg_img = load(aseg_nifti)
    aseg_data = aseg_img.get_data()
    
    # list indices for each tissue type (from freesurfer aseg)
    wm = [2, 7, 41, 46, 60, 28, 16, 77, 251, 252, 253, 254, 255]
    gm = [3, 6, 8, 9, 10, 11, 12, 13, 17, 18, 26, 42, 47, 49, 50, 51, 52, 53, 54, 58]
    csf = [4, 5, 14, 15, 24, 63]
    non_gm = wm + csf
    whole_brain = wm + gm + csf
    
    # preallocate zeros for the tissue masks
    wm_combined = zeros(aseg_data.shape)
    gm_combined = zeros(aseg_data.shape)
    csf_combined = zeros(aseg_data.shape)
    non_gm_combined = zeros(aseg_data.shape)
    whole_brain_combined = zeros(aseg_data.shape)
    
    # put labels into lists to make looping easier
    tissues_idx = [wm, gm, csf, non_gm, whole_brain]
    tissues_data = [wm_combined, gm_combined, csf_combined, non_gm_combined, whole_brain_combined]
    tissue_name = ['wm','gm','csf','non_gm','whole_brain']
    
    # initialize the binarize class
    binarize = Binarize()
    binarize.inputs.min = 0.5
    binarize.inputs.dilate = 1
    binarize.inputs.erode = 1
    
    # isolate labels for specific regions
    for x in range(0,5):
        for label in tissues_idx[x]:
            tissues_data[x][aseg_data==label] = 1
        tmp_img = Nifti1Image(tissues_data[x],header=aseg_img.header, affine=aseg_img.affine)
        save(tmp_img, tissue_name[x] + '_mask.nii.gz')
         
        binarize.inputs.in_file = abspath(tissue_name[x] + '_mask.nii.gz')
        binarize.inputs.binary_file = tissue_name[x] + '_mask.nii.gz'
        binarize.run()
    
    # make dilated brain mask
    binarize.inputs.in_file = abspath('whole_brain_mask.nii.gz')
    binarize.inputs.binary_file = 'whole_brain_D1_mask.nii.gz'
    binarize.inputs.dilate = 1
    binarize.inputs.erode = 0
    binarize.run()
    
    # gather up the mask filepaths to return
    wm_csf_mask = abspath('non_gm_mask.nii.gz')
    brain_mask = abspath('whole_brain_mask.nii.gz')
    gm_only_mask = abspath('gm_mask.nii.gz')
    brain_mask_dilated = abspath('whole_brain_D1_mask.nii.gz')
    
    return(wm_csf_mask, brain_mask, gm_only_mask, brain_mask_dilated)

def invert_masks(mask_file):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nibabel import load, save, Nifti1Image
    from os.path import abspath, basename
    from numpy import zeros
    
    # load mask data
    mask_img = load(mask_file)
    mask_data = mask_img.get_data()
    
    # preallocate new mask data
    inv_data = zeros(mask_data.shape)
    
    # invert the 1s and 0s
    inv_data[mask_data==0] = 1
    
    #save as a new file
    inv_img = Nifti1Image(inv_data, header = mask_img.header, affine = mask_img.affine)
    save(inv_img, 'inverted_' + basename(mask_file))
    inverted_mask = abspath('inverted_' + basename(mask_file))
    
    return(inverted_mask)

# %%
# FreeSurferSource node to grab processed T1w data from freesurfer
t1w_source = Node(FreeSurferSource(subjects_dir=fs_dir), name='t1w_source')

# resample brain file
resample_anat = Node(MRIConvert(vox_size=resampled_voxel_size, 
                                out_type='niigz', out_file='resampled_anat.nii.gz'), name='resample_anat')

# resample segmentation file
resample_seg = Node(MRIConvert(vox_size=resampled_voxel_size, 
                               resample_type='nearest', 
                               out_type='niigz'), name='resample_seg')

# make masks
make_masks = Node(Function(input_names=['aseg_nifti'], 
                           output_names=['wm_csf_mask', 'brain_mask', 'gm_only_mask', 'brain_mask_dilated'], 
                           function=make_masks_freesurfer), name='make_masks')

#invert the brain mask
invert_mask = Node(Function(input_names=['mask_file'], 
                            output_names=['inverted_mask'], 
                            function=invert_masks), name='invert_mask')

# %%
anatpreproc = Workflow(name='fmri_anat_preprocflow')
anatpreproc.connect([(subinfosource, t1w_source, [('subject_id','subject_id')]),
                     (t1w_source, resample_anat, [('brain','in_file')]),
                     (t1w_source, resample_seg, [('aseg','in_file')]),
                     (resample_seg, make_masks, [('out_file','aseg_nifti')]),
                     (make_masks, invert_mask, [('brain_mask','mask_file')]),
                     
                     (make_masks, datasink, [('wm_csf_mask','wm_csf_mask'),
                                             ('brain_mask','brain_mask'),
                                             ('gm_only_mask','gm_mask'),
                                             ('brain_mask_dilated','brain_mask_dilated')]),
                     (resample_anat, datasink, [('out_file','resampled_t1w_anat')]),
                     (invert_mask, datasink, [('inverted_mask','background_mask')])
                    ])
anatpreproc.base_dir = workflow_dir
anatpreproc.write_graph(graph2use='flat')
anatpreproc.run('MultiProc', plugin_args={'n_procs': proc_cores})

# %% [markdown]
# ## Preprocess fMRI resting state data
# These nodes and workflow (preprocflow) perform basic preprocessing to align the functional volumes into a common space.
# 1. Reorient images to standard space
# 2. Reslice the structural image to 2mm isotropic
# 3. Functional image slice time correction
# 4. Rigid realignment to first volume of functional image
# 5. Coregistration of functional images to structural image

# %%
## File handling Nodes
anat_template = {'brain_mask': output_dir + '/brain_mask_dilated/{subject_id}/whole_brain_D1_mask.nii.gz',
                 'resliced_anat': output_dir + '/resampled_t1w_anat/{subject_id}/resampled_anat.nii.gz'}
selectanat = Node(SelectFiles(anat_template), name='selectanat')

# Data grabber- select fMRI
func_template = {'func':raw_data + '/%s/FUNC_NIFTIS/*.nii.gz'}
selectfunc = Node(DataGrabber(base_directory = raw_data, 
                              field_template = func_template,
                              template=raw_data + '/%s/FUNC_NIFTIS/*.nii.gz',
                              sort_filelist=True,
                              in_fields=['subject_id'],
                              outfields=['func'],
                              template_args={'func':[['subject_id']]}), name='selectfunc')

# %%
# Data QC nodes
def create_coreg_plot(epi,anat):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    from nipype.interfaces.nipy.preprocess import Trim
    from os.path import abspath
    
    tr = Trim()
    tr.inputs.in_file = epi
    tr.inputs.end_index = 1
    tr.inputs.out_file = 'firstvol.nii.gz'
    tr.run()
    
    epi = abspath('firstvol.nii.gz')
    
    coreg_filename='coregistration.png'
    display = plotting.plot_anat(epi, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'coregistration to anatomy')
    display.add_edges(anat)
    display.savefig(coreg_filename) 
    display.close()
    coreg_file = abspath(coreg_filename)
    
    return(coreg_file)

def norm_timeseries(in_file, mask):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    from nilearn.masking import apply_mask, unmask
    from sklearn.preprocessing import StandardScaler
    
    raw_data = apply_mask(in_file, mask)
    scaler = StandardScaler(with_mean=True)
    norm_data = scaler.fit_transform(raw_data)
    img = unmask(norm_data, mask)
    img.to_filename('norm_func.nii.gz')
    out_file = abspath('norm_func.nii.gz')
    return(out_file)

# %%
## Nodes for preprocessing

#Slice timing correction based on interleaved acquisition using FSL
slicetime_correct = MapNode(SliceTimer(interleaved=interleave, 
                                       custom_timings=custom_timings,
                                       time_repetition=TR, 
                                       out_file='st_func.nii.gz'),
                            name='slicetime_correct', iterfield=['in_file'])
# Rigid realignment
realign = MapNode(MCFLIRT(out_file='rest_moco.nii.gz'), 
                  name='realign', iterfield=['in_file'])

# compute DVARS and FD
calc_dvars = MapNode(MotionOutliers(out_metric_values='out_mot_metric.txt',
                                    out_metric_plot='plot.png', metric='dvars'),
                     name='calc_dvars',iterfield=['in_file'])

calc_fd = MapNode(MotionOutliers(out_metric_values='out_mot_metric.txt',
                                 out_metric_plot='plot.png', metric='fd'),
                  name='calc_fd',iterfield=['in_file'])

# Registration- using bbregister
coreg = MapNode(BBRegister(contrast_type='bold', subjects_dir=fs_dir), 
                name='coreg', iterfield=['source_file'])

# Create image to check for accurate coregistration
make_coreg_img = MapNode(Function(input_names=['epi','anat'],
                                  output_names=['coreg_file'],
                                  function=create_coreg_plot),
                         name='make_coreg_img',iterfield=['epi'])

# normalize data within each run
normalize = MapNode(Function(input_names=['in_file','mask_file'], 
                             output_names=['out_file'], 
                             function=norm_timeseries), 
                    name='normalize', iterfield=['in_file'])

# %%
## Preprocessing Workflow
fmripreproc = Workflow(name='fmri_preprocflow')
fmripreproc.connect([(subinfosource,selectanat,[('subject_id','subject_id')]), 
                     (subinfosource,selectfunc,[('subject_id','subject_id')]), 
                     (subinfosource,coreg,[('subject_id','subject_id')]), 
                     
                     (selectfunc,slicetime_correct,[('func','in_file')]),
                     (slicetime_correct,realign,[('slice_time_corrected_file','in_file')]),
                     (slicetime_correct,calc_dvars,[('slice_time_corrected_file','in_file')]),
                     (slicetime_correct,calc_fd,[('slice_time_corrected_file','in_file')]),
                     (realign,coreg,[('out_file','in_file')]),
                     (coreg,normalize,[('registered_file','in_file')]),
                     
                     (selectanat,make_coreg_img,[('resliced_anat','anat')]),
                     (selectanat,normalize,[('brain_mask','mask')]),
                     (coreg,make_coreg_img,[('registered_file','epi')]),
                     (make_coreg_img,datasink,[('coreg_file','coreg_image')]),
                   
                     (realign, datasink,[('par_file','motion_parameters')]),
                     (calc_dvars, datasink,[('out_metric_plot','dvars_plot'),
                                            ('out_metric_values','dvars_values')]),
                     (calc_fd, datasink, [('out_metric_plot','fd_plot'),
                                          ('out_metric_values','fd_values')]),
                     (normalize, datasink, [('out_file','registered_func')])
                    ])
fmripreproc.base_dir = workflow_dir
fmripreproc.write_graph(graph2use='flat')
fmripreproc.run('MultiProc', plugin_args={'n_procs': proc_cores})
# Out:
# 200106-14:07:32,459 nipype.workflow INFO:
# 	 Generated workflow graph: /moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/graph.png (graph2use=flat, simple_form=True).
# 200106-14:07:32,485 nipype.workflow INFO:
# 	 Workflow fmri_preprocflow settings: ['check', 'execution', 'logging', 'monitoring']
# 200106-14:07:32,557 nipype.workflow INFO:
# 	 Running in parallel.
# 200106-14:07:32,562 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 6/6.
# 200106-14:07:32,658 nipype.workflow INFO:
# 	 [Node] Setting-up "fmri_preprocflow.selectanat" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/selectanat".
# 200106-14:07:32,659 nipype.workflow INFO:
# 	 [Node] Setting-up "fmri_preprocflow.selectfunc" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/selectfunc".
# 200106-14:07:32,665 nipype.workflow INFO:
# 	 [Node] Setting-up "fmri_preprocflow.selectfunc" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_3000/selectfunc".
# 200106-14:07:32,666 nipype.workflow INFO:
# 	 [Node] Setting-up "fmri_preprocflow.selectanat" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_3000/selectanat".
# 200106-14:07:32,741 nipype.workflow INFO:
# 	 [Node] Running "selectanat" ("nipype.interfaces.io.SelectFiles")
# 200106-14:07:32,747 nipype.workflow INFO:
# 	 [Node] Running "selectanat" ("nipype.interfaces.io.SelectFiles")
# 200106-14:07:32,754 nipype.workflow INFO:
# 	 [Node] Running "selectfunc" ("nipype.interfaces.io.DataGrabber")
# 200106-14:07:32,762 nipype.workflow INFO:
# 	 [Node] Running "selectfunc" ("nipype.interfaces.io.DataGrabber")
# 200106-14:07:32,855 nipype.workflow INFO:
# 	 [Node] Finished "fmri_preprocflow.selectfunc".
# 200106-14:07:32,863 nipype.workflow INFO:
# 	 [Node] Finished "fmri_preprocflow.selectanat".
# 200106-14:07:32,864 nipype.workflow INFO:
# 	 [Node] Finished "fmri_preprocflow.selectanat".
# 200106-14:07:33,81 nipype.workflow INFO:
# 	 [Node] Finished "fmri_preprocflow.selectfunc".
# 200106-14:07:34,567 nipype.workflow INFO:
# 	 [Job 0] Completed (fmri_preprocflow.selectfunc).
# 200106-14:07:34,572 nipype.workflow INFO:
# 	 [Job 6] Completed (fmri_preprocflow.selectanat).
# 200106-14:07:34,575 nipype.workflow INFO:
# 	 [Job 10] Completed (fmri_preprocflow.selectfunc).
# 200106-14:07:34,577 nipype.workflow INFO:
# 	 [Job 16] Completed (fmri_preprocflow.selectanat).
# 200106-14:07:34,580 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 6/6.
# 200106-14:07:36,569 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 63 jobs ready. Free memory (GB): 56.55/56.55, Free processors: 6/6.
# 200106-14:07:36,676 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct0" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct0".
# 200106-14:07:36,680 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct1" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct1".
# 200106-14:07:36,684 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct2" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct2".
# 200106-14:07:36,744 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct3" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct3".
# 200106-14:07:36,804 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct4" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct4".
# 200106-14:07:36,811 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct5" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct5".
# 200106-14:07:36,912 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct4" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/mlpe3_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:07:36,929 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct5" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/mlpe3_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:07:36,941 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct0" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/mlpe1_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:07:36,943 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct1" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/mlpe1_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:07:36,944 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct2" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/mlpe2_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:07:36,947 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct3" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/mlpe2_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:07:38,569 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 57 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct5
#                        * _slicetime_correct4
#                        * _slicetime_correct3
#                        * _slicetime_correct2
#                        * _slicetime_correct1
#                        * _slicetime_correct0
# 200106-14:13:36,83 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct1".
# 200106-14:13:36,88 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct4".
# 200106-14:13:36,95 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct3".
# 200106-14:13:36,100 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct2".
# 200106-14:13:36,950 nipype.workflow INFO:
# 	 [Job 21] Completed (_slicetime_correct1).
# 200106-14:13:36,954 nipype.workflow INFO:
# 	 [Job 22] Completed (_slicetime_correct2).
# 200106-14:13:36,957 nipype.workflow INFO:
# 	 [Job 23] Completed (_slicetime_correct3).
# 200106-14:13:36,958 nipype.workflow INFO:
# 	 [Job 24] Completed (_slicetime_correct4).
# 200106-14:13:36,962 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 57 jobs ready. Free memory (GB): 56.15/56.55, Free processors: 4/6.
#                      Currently running:
#                        * _slicetime_correct5
#                        * _slicetime_correct0
# 200106-14:13:37,104 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct6" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct6".
# 200106-14:13:37,108 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct7" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct7".
# 200106-14:13:37,114 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct8" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct8".
# 200106-14:13:37,124 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct9" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct9".
# 200106-14:13:37,168 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct6" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/mlpe4_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:13:37,170 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct7" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/mlpe4_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:13:37,176 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct8" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest1_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:13:37,182 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct9" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest1_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:13:38,954 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 53 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct9
#                        * _slicetime_correct8
#                        * _slicetime_correct7
#                        * _slicetime_correct6
#                        * _slicetime_correct5
#                        * _slicetime_correct0
# 200106-14:13:56,38 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct0".
# 200106-14:13:57,68 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct5".
# 200106-14:13:58,973 nipype.workflow INFO:
# 	 [Job 20] Completed (_slicetime_correct0).
# 200106-14:13:58,976 nipype.workflow INFO:
# 	 [Job 25] Completed (_slicetime_correct5).
# 200106-14:13:58,980 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 53 jobs ready. Free memory (GB): 55.75/56.55, Free processors: 2/6.
#                      Currently running:
#                        * _slicetime_correct9
#                        * _slicetime_correct8
#                        * _slicetime_correct7
#                        * _slicetime_correct6
# 200106-14:14:00,234 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct10" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct10".
# 200106-14:14:00,598 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct11" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct11".
# 200106-14:14:00,812 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct11" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest2_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:14:00,812 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct10" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest2_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:14:00,976 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 51 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct11
#                        * _slicetime_correct10
#                        * _slicetime_correct9
#                        * _slicetime_correct8
#                        * _slicetime_correct7
#                        * _slicetime_correct6
# 200106-14:14:47,135 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct8".
# 200106-14:14:49,26 nipype.workflow INFO:
# 	 [Job 28] Completed (_slicetime_correct8).
# 200106-14:14:49,31 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 51 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _slicetime_correct11
#                        * _slicetime_correct10
#                        * _slicetime_correct9
#                        * _slicetime_correct7
#                        * _slicetime_correct6
# 200106-14:14:49,138 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct12" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct12".
# 200106-14:14:49,182 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct12" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest3_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:14:51,30 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 50 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct12
#                        * _slicetime_correct11
#                        * _slicetime_correct10
#                        * _slicetime_correct9
#                        * _slicetime_correct7
#                        * _slicetime_correct6
# 200106-14:15:09,0 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct9".
# 200106-14:15:09,48 nipype.workflow INFO:
# 	 [Job 29] Completed (_slicetime_correct9).
# 200106-14:15:09,52 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 50 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _slicetime_correct12
#                        * _slicetime_correct11
#                        * _slicetime_correct10
#                        * _slicetime_correct7
#                        * _slicetime_correct6
# 200106-14:15:09,147 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct13" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct13".
# 200106-14:15:09,186 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct13" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest3_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:15:09,872 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct10".
# 200106-14:15:11,50 nipype.workflow INFO:
# 	 [Job 30] Completed (_slicetime_correct10).
# 200106-14:15:11,55 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 49 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _slicetime_correct13
#                        * _slicetime_correct12
#                        * _slicetime_correct11
#                        * _slicetime_correct7
#                        * _slicetime_correct6
# 200106-14:15:11,354 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct14" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct14".
# 200106-14:15:11,750 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct14" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest4_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:15:13,52 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 48 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct14
#                        * _slicetime_correct13
#                        * _slicetime_correct12
#                        * _slicetime_correct11
#                        * _slicetime_correct7
#                        * _slicetime_correct6
# 200106-14:15:55,474 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct12".
# 200106-14:15:57,100 nipype.workflow INFO:
# 	 [Job 32] Completed (_slicetime_correct12).
# 200106-14:15:57,104 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 48 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _slicetime_correct14
#                        * _slicetime_correct13
#                        * _slicetime_correct11
#                        * _slicetime_correct7
#                        * _slicetime_correct6
# 200106-14:15:57,214 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct15" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct15".
# 200106-14:15:57,260 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct15" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest4_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:15:59,104 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 47 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct15
#                        * _slicetime_correct14
#                        * _slicetime_correct13
#                        * _slicetime_correct11
#                        * _slicetime_correct7
#                        * _slicetime_correct6
# 200106-14:16:18,159 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct11".
# 200106-14:16:18,899 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct14".
# 200106-14:16:19,124 nipype.workflow INFO:
# 	 [Job 31] Completed (_slicetime_correct11).
# 200106-14:16:19,126 nipype.workflow INFO:
# 	 [Job 34] Completed (_slicetime_correct14).
# 200106-14:16:19,136 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 47 jobs ready. Free memory (GB): 55.75/56.55, Free processors: 2/6.
#                      Currently running:
#                        * _slicetime_correct15
#                        * _slicetime_correct13
#                        * _slicetime_correct7
#                        * _slicetime_correct6
# 200106-14:16:19,251 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct16" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct16".
# 200106-14:16:19,254 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct17" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct17".
# 200106-14:16:19,360 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct16" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest5_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:16:19,361 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct17" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest5_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:16:21,128 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 45 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct17
#                        * _slicetime_correct16
#                        * _slicetime_correct15
#                        * _slicetime_correct13
#                        * _slicetime_correct7
#                        * _slicetime_correct6
# 200106-14:18:01,852 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct15".
# 200106-14:18:01,885 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct16".
# 200106-14:18:01,899 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct13".
# 200106-14:18:01,903 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct6".
# 200106-14:18:03,234 nipype.workflow INFO:
# 	 [Job 26] Completed (_slicetime_correct6).
# 200106-14:18:03,236 nipype.workflow INFO:
# 	 [Job 33] Completed (_slicetime_correct13).
# 200106-14:18:03,239 nipype.workflow INFO:
# 	 [Job 35] Completed (_slicetime_correct15).
# 200106-14:18:03,241 nipype.workflow INFO:
# 	 [Job 36] Completed (_slicetime_correct16).
# 200106-14:18:03,244 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 45 jobs ready. Free memory (GB): 56.15/56.55, Free processors: 4/6.
#                      Currently running:
#                        * _slicetime_correct17
#                        * _slicetime_correct7
# 200106-14:18:03,330 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct18" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct18".
# 200106-14:18:03,335 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct19" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct19".
# 200106-14:18:03,339 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct20" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct20".
# 200106-14:18:03,352 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct21" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct21".
# 200106-14:18:03,395 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct18" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest6_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:18:03,395 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct19" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest6_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:18:03,402 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct20" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest6_3_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:18:03,408 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct21" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest7_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:18:05,238 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 41 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct21
#                        * _slicetime_correct20
#                        * _slicetime_correct19
#                        * _slicetime_correct18
#                        * _slicetime_correct17
#                        * _slicetime_correct7
# 200106-14:18:10,507 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct7".
# 200106-14:18:11,242 nipype.workflow INFO:
# 	 [Job 27] Completed (_slicetime_correct7).
# 200106-14:18:11,247 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 41 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _slicetime_correct21
#                        * _slicetime_correct20
#                        * _slicetime_correct19
#                        * _slicetime_correct18
#                        * _slicetime_correct17
# 200106-14:18:11,468 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct22" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct22".
# 200106-14:18:12,57 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct22" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest7_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:18:13,246 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 40 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct22
#                        * _slicetime_correct21
#                        * _slicetime_correct20
#                        * _slicetime_correct19
#                        * _slicetime_correct18
#                        * _slicetime_correct17
# 200106-14:18:48,371 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct17".
# 200106-14:18:49,283 nipype.workflow INFO:
# 	 [Job 37] Completed (_slicetime_correct17).
# 200106-14:18:49,288 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 40 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _slicetime_correct22
#                        * _slicetime_correct21
#                        * _slicetime_correct20
#                        * _slicetime_correct19
#                        * _slicetime_correct18
# 200106-14:18:49,377 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct23" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct23".
# 200106-14:18:49,422 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct23" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest7_3_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:18:51,287 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 39 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct23
#                        * _slicetime_correct22
#                        * _slicetime_correct21
#                        * _slicetime_correct20
#                        * _slicetime_correct19
#                        * _slicetime_correct18
# 200106-14:19:20,427 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct19".
# 200106-14:19:20,430 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct18".
# 200106-14:19:20,430 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct21".
# 200106-14:19:21,107 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct22".
# 200106-14:19:21,318 nipype.workflow INFO:
# 	 [Job 38] Completed (_slicetime_correct18).
# 200106-14:19:21,322 nipype.workflow INFO:
# 	 [Job 39] Completed (_slicetime_correct19).
# 200106-14:19:21,324 nipype.workflow INFO:
# 	 [Job 41] Completed (_slicetime_correct21).
# 200106-14:19:21,326 nipype.workflow INFO:
# 	 [Job 42] Completed (_slicetime_correct22).
# 200106-14:19:21,330 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 39 jobs ready. Free memory (GB): 56.15/56.55, Free processors: 4/6.
#                      Currently running:
#                        * _slicetime_correct23
#                        * _slicetime_correct20
# 200106-14:19:21,446 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct24" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct24".
# 200106-14:19:21,448 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct25" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct25".
# 200106-14:19:21,453 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct26" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct26".
# 200106-14:19:21,464 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct0" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_3000/slicetime_correct/mapflow/_slicetime_correct0".
# 200106-14:19:21,508 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct24" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest8_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:19:21,510 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct25" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest8_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:19:21,514 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct26" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/4000/FUNC_NIFTIS/rest9_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:19:21,522 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct0" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/3000/FUNC_NIFTIS/mlpe1_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:19:23,322 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 35 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct0
#                        * _slicetime_correct26
#                        * _slicetime_correct25
#                        * _slicetime_correct24
#                        * _slicetime_correct23
#                        * _slicetime_correct20
# 200106-14:19:57,901 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct23".
# 200106-14:19:59,359 nipype.workflow INFO:
# 	 [Job 43] Completed (_slicetime_correct23).
# 200106-14:19:59,363 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 35 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _slicetime_correct0
#                        * _slicetime_correct26
#                        * _slicetime_correct25
#                        * _slicetime_correct24
#                        * _slicetime_correct20
# 200106-14:20:00,841 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct1" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_3000/slicetime_correct/mapflow/_slicetime_correct1".
# 200106-14:20:01,363 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 34 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct1
#                        * _slicetime_correct0
#                        * _slicetime_correct26
#                        * _slicetime_correct25
#                        * _slicetime_correct24
#                        * _slicetime_correct20
# 200106-14:20:03,198 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct1" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/3000/FUNC_NIFTIS/mlpe1_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:20:27,910 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct26".
# 200106-14:20:29,390 nipype.workflow INFO:
# 	 [Job 46] Completed (_slicetime_correct26).
# 200106-14:20:29,395 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 34 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _slicetime_correct1
#                        * _slicetime_correct0
#                        * _slicetime_correct25
#                        * _slicetime_correct24
#                        * _slicetime_correct20
# 200106-14:20:32,245 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 33 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct2
#                        * _slicetime_correct1
#                        * _slicetime_correct0
#                        * _slicetime_correct25
#                        * _slicetime_correct24
#                        * _slicetime_correct20
# 200106-14:20:32,476 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct2" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_3000/slicetime_correct/mapflow/_slicetime_correct2".
# 200106-14:20:33,199 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct2" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/3000/FUNC_NIFTIS/mlpe1_3_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:20:36,373 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct20".
# 200106-14:20:38,249 nipype.workflow INFO:
# 	 [Job 40] Completed (_slicetime_correct20).
# 200106-14:20:38,255 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 33 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _slicetime_correct2
#                        * _slicetime_correct1
#                        * _slicetime_correct0
#                        * _slicetime_correct25
#                        * _slicetime_correct24
# 200106-14:20:39,593 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct3" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_3000/slicetime_correct/mapflow/_slicetime_correct3".
# 200106-14:20:40,215 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct3" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/3000/FUNC_NIFTIS/mlpe2_1_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:20:40,249 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 32 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct3
#                        * _slicetime_correct2
#                        * _slicetime_correct1
#                        * _slicetime_correct0
#                        * _slicetime_correct25
#                        * _slicetime_correct24
# 200106-14:21:38,964 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct24".
# 200106-14:21:40,313 nipype.workflow INFO:
# 	 [Job 44] Completed (_slicetime_correct24).
# 200106-14:21:40,317 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 32 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _slicetime_correct3
#                        * _slicetime_correct2
#                        * _slicetime_correct1
#                        * _slicetime_correct0
#                        * _slicetime_correct25
# 200106-14:21:40,411 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct4" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_3000/slicetime_correct/mapflow/_slicetime_correct4".
# 200106-14:21:40,452 nipype.workflow INFO:
# 	 [Node] Running "_slicetime_correct4" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/moochie/study_data/5YOP/MRI_processing/3000/FUNC_NIFTIS/mlpe2_2_unwarped.nii.gz --tcustom=/moochie/user_data/CamachoCat/5YOP/misc/slice_timing.txt --odd --out=st_func.nii.gz --repeat=1.100000
# 200106-14:21:42,318 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 31 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _slicetime_correct4
#                        * _slicetime_correct3
#                        * _slicetime_correct2
#                        * _slicetime_correct1
#                        * _slicetime_correct0
#                        * _slicetime_correct25
# 200106-14:23:17,650 nipype.workflow INFO:
# 	 [Node] Finished "_slicetime_correct25".
# 200106-14:23:18,420 nipype.workflow INFO:
# 	 [Job 45] Completed (_slicetime_correct25).
# 200106-14:23:18,425 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 32 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _slicetime_correct4
#                        * _slicetime_correct3
#                        * _slicetime_correct2
#                        * _slicetime_correct1
#                        * _slicetime_correct0
# 200106-14:23:19,866 nipype.workflow INFO:
# 	 [Node] Setting-up "fmri_preprocflow.slicetime_correct" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct".
# 200106-14:23:19,921 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct0" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct0".
# 200106-14:23:19,933 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct0" - collecting precomputed outputs
# 200106-14:23:19,934 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct0" found cached.
# 200106-14:23:19,938 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct1" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct1".
# 200106-14:23:19,961 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct1" - collecting precomputed outputs
# 200106-14:23:19,962 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct1" found cached.
# 200106-14:23:19,965 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct2" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct2".
# 200106-14:23:20,6 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct2" - collecting precomputed outputs
# 200106-14:23:20,8 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct2" found cached.
# 200106-14:23:20,13 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct3" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct3".
# 200106-14:23:20,47 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct3" - collecting precomputed outputs
# 200106-14:23:20,50 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct3" found cached.
# 200106-14:23:20,55 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct4" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct4".
# 200106-14:23:20,81 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct4" - collecting precomputed outputs
# 200106-14:23:20,82 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct4" found cached.
# 200106-14:23:20,87 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct5" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct5".
# 200106-14:23:20,107 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct5" - collecting precomputed outputs
# 200106-14:23:20,108 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct5" found cached.
# 200106-14:23:20,113 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct6" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct6".
# 200106-14:23:20,132 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct6" - collecting precomputed outputs
# 200106-14:23:20,133 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct6" found cached.
# 200106-14:23:20,138 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct7" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct7".
# 200106-14:23:20,180 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct7" - collecting precomputed outputs
# 200106-14:23:20,181 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct7" found cached.
# 200106-14:23:20,188 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct8" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct8".
# 200106-14:23:20,226 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct8" - collecting precomputed outputs
# 200106-14:23:20,227 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct8" found cached.
# 200106-14:23:20,234 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct9" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct9".
# 200106-14:23:20,247 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct9" - collecting precomputed outputs
# 200106-14:23:20,249 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct9" found cached.
# 200106-14:23:20,273 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct10" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct10".
# 200106-14:23:20,417 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct10" - collecting precomputed outputs
# 200106-14:23:20,419 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct10" found cached.
# 200106-14:23:20,422 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 31 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * fmri_preprocflow.slicetime_correct
#                        * _slicetime_correct4
#                        * _slicetime_correct3
#                        * _slicetime_correct2
#                        * _slicetime_correct1
#                        * _slicetime_correct0
# 200106-14:23:20,695 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct11" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct11".
# 200106-14:23:20,729 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct11" - collecting precomputed outputs
# 200106-14:23:20,731 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct11" found cached.
# 200106-14:23:20,737 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct12" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct12".
# 200106-14:23:20,773 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct12" - collecting precomputed outputs
# 200106-14:23:20,776 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct12" found cached.
# 200106-14:23:20,783 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct13" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct13".
# 200106-14:23:20,816 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct13" - collecting precomputed outputs
# 200106-14:23:20,817 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct13" found cached.
# 200106-14:23:20,822 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct14" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct14".
# 200106-14:23:20,872 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct14" - collecting precomputed outputs
# 200106-14:23:20,874 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct14" found cached.
# 200106-14:23:20,882 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct15" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct15".
# 200106-14:23:20,908 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct15" - collecting precomputed outputs
# 200106-14:23:20,909 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct15" found cached.
# 200106-14:23:20,914 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct16" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct16".
# 200106-14:23:20,926 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct16" - collecting precomputed outputs
# 200106-14:23:20,927 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct16" found cached.
# 200106-14:23:20,934 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct17" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct17".
# 200106-14:23:20,968 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct17" - collecting precomputed outputs
# 200106-14:23:20,970 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct17" found cached.
# 200106-14:23:20,977 nipype.workflow INFO:
# 	 [Node] Setting-up "_slicetime_correct18" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct18".
# 200106-14:23:20,998 nipype.workflow INFO:
# 	 [Node] Cached "_slicetime_correct18" - collecting precomputed outputs
# 200106-14:23:20,999 nipype.workflow INFO:
# 	 [Node] "_slicetime_correct18" found cached.
# 200106-14:23:21,6 nipype.workflow INFO:
# ...
# 	 [Node] Cached "_calc_fd8" - collecting precomputed outputs
# 200106-15:11:32,662 nipype.workflow INFO:
# 	 [Node] "_calc_fd8" found cached.
# 200106-15:11:32,667 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd9" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd9".
# 200106-15:11:32,703 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd9" - collecting precomputed outputs
# 200106-15:11:32,705 nipype.workflow INFO:
# 	 [Node] "_calc_fd9" found cached.
# 200106-15:11:32,710 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd10" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd10".
# 200106-15:11:32,723 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd10" - collecting precomputed outputs
# 200106-15:11:32,725 nipype.workflow INFO:
# 	 [Node] "_calc_fd10" found cached.
# 200106-15:11:32,730 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd11" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd11".
# 200106-15:11:32,760 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd11" - collecting precomputed outputs
# 200106-15:11:32,763 nipype.workflow INFO:
# 	 [Node] "_calc_fd11" found cached.
# 200106-15:11:32,769 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd12" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd12".
# 200106-15:11:32,799 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd12" - collecting precomputed outputs
# 200106-15:11:32,800 nipype.workflow INFO:
# 	 [Node] "_calc_fd12" found cached.
# 200106-15:11:32,806 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd13" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd13".
# 200106-15:11:32,886 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd13" - collecting precomputed outputs
# 200106-15:11:32,887 nipype.workflow INFO:
# 	 [Node] "_calc_fd13" found cached.
# 200106-15:11:32,891 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd14" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd14".
# 200106-15:11:32,916 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd14" - collecting precomputed outputs
# 200106-15:11:32,917 nipype.workflow INFO:
# 	 [Node] "_calc_fd14" found cached.
# 200106-15:11:32,921 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd15" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd15".
# 200106-15:11:32,943 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd15" - collecting precomputed outputs
# 200106-15:11:32,945 nipype.workflow INFO:
# 	 [Node] "_calc_fd15" found cached.
# 200106-15:11:32,950 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd16" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd16".
# 200106-15:11:32,991 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd16" - collecting precomputed outputs
# 200106-15:11:32,993 nipype.workflow INFO:
# 	 [Node] "_calc_fd16" found cached.
# 200106-15:11:32,998 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd17" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd17".
# 200106-15:11:33,68 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd17" - collecting precomputed outputs
# 200106-15:11:33,69 nipype.workflow INFO:
# 	 [Node] "_calc_fd17" found cached.
# 200106-15:11:33,73 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd18" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd18".
# 200106-15:11:33,89 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd18" - collecting precomputed outputs
# 200106-15:11:33,91 nipype.workflow INFO:
# 	 [Node] "_calc_fd18" found cached.
# 200106-15:11:33,97 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd19" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd19".
# 200106-15:11:33,128 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd19" - collecting precomputed outputs
# 200106-15:11:33,129 nipype.workflow INFO:
# 	 [Node] "_calc_fd19" found cached.
# 200106-15:11:33,135 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd20" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd20".
# 200106-15:11:33,146 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd20" - collecting precomputed outputs
# 200106-15:11:33,147 nipype.workflow INFO:
# 	 [Node] "_calc_fd20" found cached.
# 200106-15:11:33,151 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd21" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd21".
# 200106-15:11:33,189 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd21" - collecting precomputed outputs
# 200106-15:11:33,190 nipype.workflow INFO:
# 	 [Node] "_calc_fd21" found cached.
# 200106-15:11:33,198 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd22" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd22".
# 200106-15:11:33,211 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd22" - collecting precomputed outputs
# 200106-15:11:33,212 nipype.workflow INFO:
# 	 [Node] "_calc_fd22" found cached.
# 200106-15:11:33,218 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd23" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd23".
# 200106-15:11:33,230 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd23" - collecting precomputed outputs
# 200106-15:11:33,231 nipype.workflow INFO:
# 	 [Node] "_calc_fd23" found cached.
# 200106-15:11:33,237 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd24" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd24".
# 200106-15:11:33,250 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd24" - collecting precomputed outputs
# 200106-15:11:33,252 nipype.workflow INFO:
# 	 [Node] "_calc_fd24" found cached.
# 200106-15:11:33,259 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd25" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd25".
# 200106-15:11:33,270 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd25" - collecting precomputed outputs
# 200106-15:11:33,271 nipype.workflow INFO:
# 	 [Node] "_calc_fd25" found cached.
# 200106-15:11:33,277 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_fd26" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_fd/mapflow/_calc_fd26".
# 200106-15:11:33,288 nipype.workflow INFO:
# 	 [Node] Cached "_calc_fd26" - collecting precomputed outputs
# 200106-15:11:33,289 nipype.workflow INFO:
# 	 [Node] "_calc_fd26" found cached.
# 200106-15:11:33,343 nipype.workflow INFO:
# 	 [Node] Finished "fmri_preprocflow.calc_fd".
# 200106-15:11:34,45 nipype.workflow INFO:
# 	 [Job 2] Completed (fmri_preprocflow.calc_fd).
# 200106-15:11:34,51 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 157 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _calc_dvars4
#                        * _calc_dvars3
#                        * _calc_dvars2
#                        * _calc_dvars1
#                        * _calc_dvars0
# 200106-15:11:34,128 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_dvars5" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_dvars/mapflow/_calc_dvars5".
# 200106-15:11:34,172 nipype.workflow INFO:
# 	 [Node] Running "_calc_dvars5" ("nipype.interfaces.fsl.utils.MotionOutliers"), a CommandLine Interface with command:
# fsl_motion_outliers -i /moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct5/st_func.nii.gz --dvars -o st_func_outliers.txt -p plot.png -s out_mot_metric.txt
# 200106-15:11:36,49 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 156 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _calc_dvars5
#                        * _calc_dvars4
#                        * _calc_dvars3
#                        * _calc_dvars2
#                        * _calc_dvars1
#                        * _calc_dvars0
# 200106-15:20:13,531 nipype.workflow INFO:
# 	 [Node] Finished "_calc_dvars0".
# 200106-15:20:14,594 nipype.workflow INFO:
# 	 [Job 110] Completed (_calc_dvars0).
# 200106-15:20:14,600 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 156 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _calc_dvars5
#                        * _calc_dvars4
#                        * _calc_dvars3
#                        * _calc_dvars2
#                        * _calc_dvars1
# 200106-15:20:14,725 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_dvars6" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_dvars/mapflow/_calc_dvars6".
# 200106-15:20:14,767 nipype.workflow INFO:
# 	 [Node] Running "_calc_dvars6" ("nipype.interfaces.fsl.utils.MotionOutliers"), a CommandLine Interface with command:
# fsl_motion_outliers -i /moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct6/st_func.nii.gz --dvars -o st_func_outliers.txt -p plot.png -s out_mot_metric.txt
# 200106-15:20:16,601 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 155 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _calc_dvars6
#                        * _calc_dvars5
#                        * _calc_dvars4
#                        * _calc_dvars3
#                        * _calc_dvars2
#                        * _calc_dvars1
# 200106-15:20:25,544 nipype.workflow INFO:
# 	 [Node] Finished "_calc_dvars1".
# 200106-15:20:26,606 nipype.workflow INFO:
# 	 [Job 111] Completed (_calc_dvars1).
# 200106-15:20:26,612 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 155 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _calc_dvars6
#                        * _calc_dvars5
#                        * _calc_dvars4
#                        * _calc_dvars3
#                        * _calc_dvars2
# 200106-15:20:27,152 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_dvars7" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_dvars/mapflow/_calc_dvars7".
# 200106-15:20:28,437 nipype.workflow INFO:
# 	 [Node] Running "_calc_dvars7" ("nipype.interfaces.fsl.utils.MotionOutliers"), a CommandLine Interface with command:
# fsl_motion_outliers -i /moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct7/st_func.nii.gz --dvars -o st_func_outliers.txt -p plot.png -s out_mot_metric.txt
# 200106-15:20:28,610 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 154 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _calc_dvars7
#                        * _calc_dvars6
#                        * _calc_dvars5
#                        * _calc_dvars4
#                        * _calc_dvars3
#                        * _calc_dvars2
# 200106-15:21:17,903 nipype.workflow INFO:
# 	 [Node] Finished "_calc_dvars2".
# 200106-15:21:18,658 nipype.workflow INFO:
# 	 [Job 112] Completed (_calc_dvars2).
# 200106-15:21:18,662 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 154 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _calc_dvars7
#                        * _calc_dvars6
#                        * _calc_dvars5
#                        * _calc_dvars4
#                        * _calc_dvars3
# 200106-15:21:18,752 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_dvars8" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_dvars/mapflow/_calc_dvars8".
# 200106-15:21:18,794 nipype.workflow INFO:
# 	 [Node] Running "_calc_dvars8" ("nipype.interfaces.fsl.utils.MotionOutliers"), a CommandLine Interface with command:
# fsl_motion_outliers -i /moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct8/st_func.nii.gz --dvars -o st_func_outliers.txt -p plot.png -s out_mot_metric.txt
# 200106-15:21:20,662 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 153 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _calc_dvars8
#                        * _calc_dvars7
#                        * _calc_dvars6
#                        * _calc_dvars5
#                        * _calc_dvars4
#                        * _calc_dvars3
# 200106-15:22:04,90 nipype.workflow INFO:
# 	 [Node] Finished "_calc_dvars3".
# 200106-15:22:04,704 nipype.workflow INFO:
# 	 [Job 113] Completed (_calc_dvars3).
# 200106-15:22:04,710 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 153 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _calc_dvars8
#                        * _calc_dvars7
#                        * _calc_dvars6
#                        * _calc_dvars5
#                        * _calc_dvars4
# 200106-15:22:04,839 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_dvars9" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_dvars/mapflow/_calc_dvars9".
# 200106-15:22:04,880 nipype.workflow INFO:
# 	 [Node] Running "_calc_dvars9" ("nipype.interfaces.fsl.utils.MotionOutliers"), a CommandLine Interface with command:
# fsl_motion_outliers -i /moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct9/st_func.nii.gz --dvars -o st_func_outliers.txt -p plot.png -s out_mot_metric.txt
# 200106-15:22:06,709 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 152 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _calc_dvars9
#                        * _calc_dvars8
#                        * _calc_dvars7
#                        * _calc_dvars6
#                        * _calc_dvars5
#                        * _calc_dvars4
# 200106-15:22:29,130 nipype.workflow INFO:
# 	 [Node] Finished "_calc_dvars4".
# 200106-15:22:30,732 nipype.workflow INFO:
# 	 [Job 114] Completed (_calc_dvars4).
# 200106-15:22:30,737 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 152 jobs ready. Free memory (GB): 55.55/56.55, Free processors: 1/6.
#                      Currently running:
#                        * _calc_dvars9
#                        * _calc_dvars8
#                        * _calc_dvars7
#                        * _calc_dvars6
#                        * _calc_dvars5
# 200106-15:22:30,835 nipype.workflow INFO:
# 	 [Node] Setting-up "_calc_dvars10" in "/moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/calc_dvars/mapflow/_calc_dvars10".
# 200106-15:22:30,876 nipype.workflow INFO:
# 	 [Node] Running "_calc_dvars10" ("nipype.interfaces.fsl.utils.MotionOutliers"), a CommandLine Interface with command:
# fsl_motion_outliers -i /moochie/user_data/CamachoCat/5YOP/workflows/fmri_preprocflow/_subject_id_4000/slicetime_correct/mapflow/_slicetime_correct10/st_func.nii.gz --dvars -o st_func_outliers.txt -p plot.png -s out_mot_metric.txt
# 200106-15:22:32,737 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 151 jobs ready. Free memory (GB): 55.35/56.55, Free processors: 0/6.
#                      Currently running:
#                        * _calc_dvars10
#                        * _calc_dvars9
#                        * _calc_dvars8
#                        * _calc_dvars7
#                        * _calc_dvars6
#                        * _calc_dvars5

# %% [markdown]
# ## Create Nuissance Regressors
# These nodes and workflow creates both the subject specific and general nuissance regressors needed for preprocessing the rest data

# %%
# Data grabber- select fMRI
func_template = {'func':output_dir + '/registered_func/%s/*/realigned_func.nii.gz'}
selectfunc = Node(DataGrabber(sort_filelist = True,
                              template = output_dir + '/registered_func/%s/*/realigned_func.nii.gz',
                              field_template = func_template,
                              base_directory = output_dir,
                              infields=['subject_id'], 
                              template_args = {'func':[['subject_id']]}), name='selectfunc')

# select motion params
mot_template={'motion':output_dir + '/motion_parameters/%s/*/rest_moco.nii.gz.par'}
selectmotion = Node(DataGrabber(sort_filelist = True,
                                template = output_dir + '/motion_parameters/%s/*/rest_moco.nii.gz.par',
                                field_template = mot_template,
                                base_directory = output_dir,
                                infields = ['subject_id'], 
                                template_args = {'motion':[['subject_id']]}), name='selectmotion')

# %%
def mask_blur_func(mask, in_file):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    from numpy import median, where
    from nipype.interfaces.fsl import ApplyMask
    from glob import glob
    from subprocess import check_call

    applymask = ApplyMask()
    applymask.inputs.mask_file = mask
    applymask.inputs.in_file = in_file
    applymask.inputs.out_file = 'masked_file.nii.gz'
    applymask.inputs.nan2zeros = True
    applymask.run()

    masked_file = abspath('masked_file.nii.gz')
    
    
    if 'nonbrain' in mask:
        check_call(['gunzip',masked_file])
        
        from nipype.interfaces.spm import Smooth
        smooth = Smooth()
        smooth.inputs.in_files = 'masked_file.nii'
        smooth.inputs.fwhm = [22,4,4]
        smooth.inputs.out_prefix = 'blurred_'
        smooth.run()
        check_call(['gzip','blurred_masked_file.nii'])
        
    else:
        from nipype.interfaces.fsl import Smooth
        smooth = Smooth()
        smooth.inputs.in_file = masked_file
        smooth.inputs.smoothed_file = 'blurred_masked_file.nii.gz'
        smooth.inputs.fwhm = 4
        smooth.run()

    blurred_masked_file = abspath('blurred_masked_file.nii.gz')

    return(blurred_masked_file)

def leadlagmatrix(motion_file):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from os.path import abspath
    import numpy as np

    motion_params = np.loadtxt(motion_file, dtype=float)
    trs = motion_params.shape[0]
    params = motion_params.shape[1]
    derivatives = np.gradient(motion_params, axis=0)
    leadlagderivs = np.zeros((trs,params*6))
    derivativessq = derivatives**2
    leadlagderivssq = np.zeros((trs,params*6))

    for i in range(0,params):
        for j in range(0,6):
            leadlagderivs[:,j+params*i] =  np.roll(derivatives[:,i],shift=j, axis=0)
            leadlagderivs[:j,j+params*i] = 0

    for i in range(0,params):
        for j in range(0,6):
            leadlagderivssq[:,j+params*i] =  np.roll(derivativessq[:,i],shift=j, axis=0)
            leadlagderivssq[:j,j+params*i] = 0

    np.savetxt('derivsleadlag.txt', leadlagderivs)
    np.savetxt('derivssqleadlag.txt', leadlagderivssq)

    leadlagderivsmot = abspath('derivsleadlag.txt')
    leadlagderivssqmot = abspath('derivssqleadlag.txt')
    
    return(leadlagderivsmot, leadlagderivssqmot)

# %%
# get scanner noise
session_noise = MapNode(Function(input_names=['mask','in_file'], 
                                 output_names=['blurred_masked_file'],
                                 function=mask_blur_func), name='session_noise', iterfield=['in_file'])
session_noise.inputs.mask=template_nonbrain

# get noise associated with WM and CSF
wmcsf_noise = MapNode(Function(input_names=['mask','in_file'], 
                               output_names=['blurred_masked_file'],
                               function=mask_blur_func), name='wmcsf_noise', iterfield=['in_file'])
wmcsf_noise.inputs.mask=template_nongm

# extract components from session nifti
comp_session_noise = MapNode(CompCor(repetition_time=TR,
                                  num_components=9,
                                  components_file='components.txt',
                                  mask_files=template_mask), 
                          name='comp_session_noise', iterfield=['realigned_file'])

# extract components from WM-CSF nifti 
comp_wmcsf_noise = MapNode(CompCor(repetition_time=TR, 
                                   num_components=9,
                                   components_file='components.txt',
                                   mask_files=template_mask), 
                           name='comp_wmcsf_noise', iterfield=['realigned_file'])

# prepare leadlag motion and derivatives
prep_motion = MapNode(Function(input_names=['motion_file'], 
                               output_names=['leadlagderivsmot','leadlagderivssqmot'],
                               function=leadlagmatrix), 
                      name='prep_motion', iterfield=['motion_file'])

# %%
create_noise_flow = Workflow(name='create_noise_flow')
create_noise_flow.connect([(subinfosource,selectfunc,[('subject_id','subject_id')]),
                           (selectfunc, wmcsf_noise, [('func','in_file')]),
                           (selectfunc, session_noise, [('func','in_file')]),
                           (wmcsf_noise, comp_wmcsf_noise, [('blurred_masked_file','realigned_file')]),
                           (session_noise, comp_session_noise, [('blurred_masked_file','realigned_file')]),
                           (wmcsf_noise, datasink, [('blurred_masked_file','wmcsf_noise_file')]),
                           (session_noise, datasink, [('blurred_masked_file','session_noise_file')]),
                           (comp_wmcsf_noise, datasink, [('components_file','subject_wmcsf_comp_noise')]),
                           (comp_session_noise, datasink, [('components_file','subject_session_comp_noise')]),
                           
                           (subinfosource,selectmotion,[('subject_id','subject_id')]),
                           (selectmotion, prep_motion, [('motion','motion_file')]),
                           (prep_motion, datasink, [('leadlagderivsmot','leadlagderivsmotion'),
                                                    ('leadlagderivssqmot','leadlagderivs_squaremotion')])
                          ])
create_noise_flow.base_dir = workflow_dir
create_noise_flow.write_graph(graph2use='flat')
create_noise_flow.run('MultiProc', plugin_args={'n_procs': 4})

# %% [markdown]
# ### Create mean volume and extract the first 9 principle components

# %%
from glob import glob
from nipype import config, logging
config.enable_debug_mode()
logging.update_logging(config)
from os import mkdir, remove
from os.path import abspath
from nibabel import load, save, Nifti1Image
import numpy as np
from subprocess import check_call

mkdir(output_dir + '/mean_func')
mf_output_dir = output_dir + '/mean_func'

in_files = glob(output_dir + '/registered_func/*/*/realigned_func.nii.gz')
    
image = load(in_files[0])
data = image.get_data()
data = np.expand_dims(data,4)
maxt = data.shape[3]

for a in range(1,len(in_files)):
    tempimg = load(in_files[a])
    tempdata = tempimg.get_data()
    if tempdata.shape[3] > maxt:
        maxt=tempdata.shape[3]

files_to_avg = []        

for a in range(0,len(in_files)):
    tempimg = load(in_files[a])
    tempdata = tempimg.get_data()
    if tempdata.shape[3] < maxt:
        padn=data.shape[3]-tempdata.shape[3]
        tempdata=np.pad(tempdata,pad_width=((0,0),(0,0),(0,0),(0,padn)),
                        mode='constant',constant_values=0)
        new_img = Nifti1Image(tempdata, affine=tempimg.affine, header=tempimg.header)
        save(new_img, 'realigned_func_pad_{0}.nii.gz'.format(a))
        files_to_avg.append(abspath('realigned_func_pad_{0}.nii.gz'.format(a)))
    elif tempdata.shape[3] == maxt:
        files_to_avg.append(in_files[a])
        
mean_file=mf_output_dir+'/mean_funcs.nii.gz'

check_call(['3dMean','-prefix',mean_file,'-non_zero'] +files_to_avg)

# %%
# extract components from averaged time series
comp_average_noise = CompCor()
comp_average_noise.inputs.realigned_file=mean_file
comp_average_noise.inputs.repetition_time=TR
comp_average_noise.inputs.num_components=9
comp_average_noise.inputs.components_file=mf_output_dir +'/components.txt' 
comp_average_noise.inputs.mask_files=template_mask
comp_average_noise.run()

# %%
import matplotlib.pyplot as plt
from pandas import read_csv

components = read_csv('/Users/catcamacho/Dropbox/temp/babies_20191010/mean_func/components.txt', 
                      index_col=None, delimiter='\t')

for comp in components.columns:
    plt.figure()
    plt.plot(components[comp])
    plt.show()
    plt.close()

# %% [markdown]
# ## Movement Noise Evaluation Workflow
#
# The nodes and workflow below (eval_noise_flow) is designed to take the nuissance regressors created in the previous section (create_noise_flow) and perform voxel-specific assessment of noise.  This is accomplished through the following steps:
# 1. Create unique design matrix for each 3D voxel
# 2. Perform a GLM for that voxel
# 3. Project results back into 3D space

# %%
sub_files_template={'motion': output_dir + '/motion_parameters/{subject_id}/_realign{runnum}/rest_moco.nii.gz.par', 
                    'leadlagderivsmotion': output_dir + '/leadlagderivsmotion/{subject_id}/_prep_motion{runnum}/derivsleadlag.txt', 
                    'leadlagderivs_squaremotion': output_dir + '/leadlagderivs_squaremotion/{subject_id}/_prep_motion{runnum}/derivssqleadlag.txt', 
                    'func': output_dir + '/registered_func/{subject_id}/_xfmFUNC{runnum}/realigned_func.nii.gz'}
select_sub_files=Node(SelectFiles(sub_files_template),name='select_sub_files')
select_sub_files.iterables=('runnum',['0','1'])

# %%
def org_shared_noise(motion, leadlagderivsmotion, leadlagderivs_squaremotion):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from numpy import loadtxt, concatenate
    from pandas import DataFrame
    from os.path import abspath
    
    noise_list = []
    for file in [motion, leadlagderivsmotion, leadlagderivs_squaremotion]:
        mo = loadtxt(file, dtype=float, comments=None)
        length_of_file = mo.shape[0]
        noise_list.append(mo)

    shared_noise_data = concatenate(noise_list,axis=1)
    
    col_names = ['noise_{0}'.format(a) for a in range(0,shared_noise_data.shape[1])] 
    
    shared_noise = DataFrame(shared_noise_data, columns=col_names)
    shared_noise.to_csv('shared_noise.csv')
    shared_noise_file = abspath('shared_noise.csv')
    return(shared_noise_file)

def voxelwise_p_eta(func,shared_noise_file,mean_func,mask):
    from os.path import abspath
    from numpy import zeros, ones
    from numpy.linalg import lstsq
    from pandas import read_csv, Series
    from nilearn.masking import apply_mask, unmask

    # import data into an array that is timepoints (rows) by voxel number (columns)
    shared_noise = read_csv(shared_noise_file, index_col=0)
    func_data = apply_mask(func, mask)
    mean_func_data = apply_mask(mean_func, mask)
    mean_func_data = mean_func_data[:func_data.shape[0],:]
    coefficients = zeros((shared_noise.shape[1]+2,func_data.shape[1]))
    num_regress_groups = (shared_noise.shape[0]-6)/3
    p_eta_data = zeros((num_regress_groups,func_data.shape[1]))
    
    # perform voxel-wise matrix inversion
    for x in range(0,func_data.shape[1]):
        shared_noise['mean_signal'] = mean_func_data[:,x]
        shared_noise['constant'] = 1
        noise_mat = shared_noise.to_numpy()
        y = func_data[:,x]
        solution = lstsq(noise_mat,y)
        coefficients[:,x] = solution[0]
        r2 = 1 - solution[1] / (shared_noise.shape[0] * y.var())
        for i in range(0,num_regress_groups):
            temp = shared_noise.drop(['noise_{0}'.format(3*i+6),'noise_{0}'.format(3*i+7),'noise_{0}'.format(3*i+8)],axis=1)
            temp_mat = temp.to_numpy()
            temp_sol = lstsq(temp_mat,y)
            temp_r2 = 1 - solution[1] / (temp_mat.shape[0] * y.var())
            p_eta_data[i,x] = r2-temp_r2  
            
    coeff_image = unmask(coefficients, mask)
    coeff_image.to_filename('weights.nii.gz')
    p_eta_image = unmask(p_eta_data, mask)
    p_eta_image.to_filename('p_eta.nii.gz')
    sample_design_df = shared_noise.to_csv('last_noise_mat.csv')

    weights = abspath('weights.nii.gz')
    p_eta = abspath('p_eta.nii.gz')
    sample_design_df = abspath('last_noise_mat.csv')

    return(weights,p_eta, sample_design_df)

# %%
compile_noise_mat = Node(Function(input_names=['motion', 'leadlagderivsmotion', 'leadlagderivs_squaremotion'],
                                  output_names=['shared_noise_file'],
                                  function=org_shared_noise), 
                         name='compile_noise_mat')
eval_noise_func = Node(Function(input_names=['func','shared_noise_file','mean_func','mask'], 
                                output_names=['weights','p_eta','sample_design_df'],
                                function=voxelwise_p_eta),
                       name='eval_noise_func')
eval_noise_func.inputs.mask = template_maskD1
eval_noise_func.inputs.mean_func = output_dir + '/mean_func/mean_funcs.nii.gz'

# %%
eval_noise_flow = Workflow(name='eval_noise_flow')
eval_noise_flow.connect([(infosource, select_sub_files,[('subject_id','subject_id')]),
                         (select_sub_files, eval_noise_func, [('func','func')]),
                         (select_sub_files, compile_noise_mat, [('motion','motion'),
                                                                ('leadlagderivsmotion','leadlagderivsmotion'), 
                                                                ('leadlagderivs_squaremotion','leadlagderivs_squaremotion')]),
                         (compile_noise_mat, eval_noise_func, [('shared_noise_file','shared_noise_file')]),
                         
                         (eval_noise_func,datasink,[('weights','denoising_weights'),
                                                    ('sample_design_df','denoise_sample_design_df'),
                                                    ('p_eta','p_eta')])
                        ])
eval_noise_flow.base_dir = workflow_dir
eval_noise_flow.write_graph(graph2use='flat')
eval_noise_flow.run('MultiProc', plugin_args={'n_procs': 3})

# %% [markdown]
# ### Assess which motion parameters are associated with systematic noise

# %%
# create mean of the parameter estimates for the noise variables

from subprocess import check_call
from glob import glob
files_to_avg = glob(output_dir + '/denoising_weights/*/*/weights.nii.gz')
check_call(['3dMean','-prefix',output_dir + '/mean_weights/mean_noise_estimates.nii.gz','-non_zero'] +files_to_avg)

files_to_avg = glob(output_dir + '/p_eta/*/*/p_eta.nii.gz')
check_call(['3dMean','-prefix',output_dir + '/mean_p_eta/p_eta_mean.nii.gz','-non_zero'] +files_to_avg)

# %%
from nilearn.masking import apply_mask
import matplotlib.pyplot as plt
from numpy import mean

p_eta_data = apply_mask(output_dir + '/mean_p_eta/p_eta_mean.nii.gz', template_gmmask)
mean_p_etas = mean(p_eta_data, axis=1)
indices_to_drop = sorted(range(len(mean_p_etas)), key=lambda i: mean_p_etas[i])[:6]
print(indices_to_drop)

noise_to_drop = []
for i in indices_to_drop:
    noise_to_drop.append('noise_{0}'.format(3*i+6))
    noise_to_drop.append('noise_{0}'.format(3*i+7))
    noise_to_drop.append('noise_{0}'.format(3*i+8))
plt.plot(mean_p_etas)

# %% [markdown]
# ## Final Denoising Workflow

# %%
sub_files_template={'func': output_dir + '/registered_func/{subject_id}/_xfmFUNC{runnum}/realigned_func.nii.gz',
                    'shared_noise_file': output_dir + '/shared_noise_file/{subject_id}/_runnum{runnum}/shared_noise.csv'}
select_sub_files=Node(SelectFiles(sub_files_template),name='select_sub_files')
select_sub_files.iterables=('runnum',['0','1'])

# %%
def voxelwise_glm(func,shared_noise_file,mean_func,mask,noise_to_drop):
    from os.path import abspath
    from numpy import zeros, dot, transpose, sum
    from numpy.linalg import pinv
    from pandas import read_csv, Series
    from nilearn.masking import apply_mask, unmask

    # import data into an array that is timepoints (rows) by voxel number (columns)
    shared_noise = read_csv(shared_noise_file, index_col=0)
    shared_noise.drop(labels=noise_to_drop, inplace=True, axis=1)
    func_data = apply_mask(func, mask)
    mean_func_data = apply_mask(mean_func, mask)
    mean_func_data = mean_func_data[:func_data.shape[0],:]
    coefficients = zeros((shared_noise.shape[1]+2,func_data.shape[1]))
    resid_data = zeros(func_data.shape)

    # perform voxel-wise matrix inversion
    for x in range(0,func_data.shape[1]):
        shared_noise['mean_signal'] = mean_func_data[:,x]
        shared_noise['constant'] = 1
        noise_mat = shared_noise.to_numpy()
        y = func_data[:,x]
        inv_mat = pinv(noise_mat)
        coefficients[:,x] = dot(inv_mat,y)
        yhat=sum(transpose(coefficients[:,x])*noise_mat,axis=1)
        resid_data[:,x] = y - transpose(yhat)

    resid_image = unmask(resid_data, mask)
    resid_image.to_filename('residuals.nii.gz')

    coeff_image = unmask(coefficients, mask)
    coeff_image.to_filename('weights.nii.gz')
    sample_design_df = shared_noise.to_csv('last_noise_mat.csv')

    weights = abspath('weights.nii.gz')
    sample_design_df = abspath('last_noise_mat.csv')
    residuals = abspath('residuals.nii.gz')

    return(weights,sample_design_df, residuals)

def convertafni(in_file):
    from nipype.interfaces.afni.utils import AFNItoNIFTI
    from os.path import abspath
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    cvt = AFNItoNIFTI()
    cvt.inputs.in_file = in_file
    cvt.inputs.out_file = 'func_filtered.nii.gz'
    cvt.run()
    
    out_file = abspath('func_filtered.nii.gz')
    return(out_file)

def drop_high_motion_trs(in_file, mask, motion):
    from os.path import abspath
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn.masking import apply_mask, unmask
    import numpy as np

    motion_params = np.loadtxt(motion)
    motion_derivs = np.gradient(motion_params, axis=0)
    fd = np.sum(np.absolute(motion_derivs),axis=1)

    func_data = apply_mask(in_file,mask)
    lomo_func = func_data[fd<0.5]
    lomo_image = unmask(lomo_func,mask)
    lomo_image.to_file('lomo_func.nii.gz')
    out_file = abspath('lomo_func.nii.gz')
    
    return(out_file)

# %%
# band pass filtering- all rates are in Hz (1/TR or samples/second)
denoise_func = Node(Function(input_names=['func','shared_noise_file','mean_func','mask','noise_to_drop'], 
                             output_names=['weights','sample_design_df','residuals'],
                             function=voxelwise_glm),
                       name='denoise_func')
denoise_func.inputs.mask = template_maskD1
denoise_func.inputs.mean_func = output_dir + '/mean_func/mean_funcs.nii.gz'
denoise_func.inputs.noise_to_drop = noise_to_drop

bandpass = Node(Bandpass(highpass=highpass_freq,
                         lowpass=lowpass_freq), 
                name='bandpass')

afni_convert = Node(Function(input_names=['in_file'],
                             output_names=['out_file'],
                             function=convertafni), 
                    name='afni_convert')

drop_himo = Node(Function(input_names=['in_file','mask','motion'], 
                          output_names=['out_file'], 
                          function=drop_high_motion_trs), 
                 name=drop_himo)

merge = JoinNode(Merge(dimension='t'), joinsource='select_sub_files', 
                 joinfield=['runnum'], name='merge')

# %%
denoise_flow = Workflow(name='denoise_flow')
denoise_flow.connect([(infosource, select_sub_files,[('subject_id','subject_id')]),
                      (select_sub_files, denoise_func, [('func','func'),
                                                        ('shared_noise_file','shared_noise_file')]),
                      (denoise_func,bandpass,[('residuals','in_file')]),
                      (bandpass,afni_convert,[('out_file','in_file')]),
                      (afni_convert, drop_himo, [('out_file','in_file')]),
                      (drop_himo,merge,[('out_file','in_files')]),
                      
                      (merge,datasink,[('out_file','fully_processed_func')]),
                      (denoise_func,datasink,[('weights','denoising_weights'),
                                              ('sample_design_df','denoise_sample_design_df')])
                     ])
denoise_flow.base_dir = workflow_dir
denoise_flow.write_graph(graph2use='flat')
denoise_flow.run('MultiProc', plugin_args={'n_procs': 3})
